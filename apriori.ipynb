# %%
#Import required libraries

#GENERAL STRUCTURE:
#Generate candidate set
#Check all subsets of each candidate. If a subset is not frequent, remove that candidate
#Search data for count of each candidate set
#Compare to min_support. If >= min_support, add to master list of freq_sets.

import pandas as pd
import itertools as itertools

# %%
salesData = pd.read_csv("Datasets/SuperCenterDataNew.csv", header=None)

# %%
salesData = salesData.head(150)

# %%
#aprior class holds attributes to be stored in an array of objects
class apriori:
    def __init__(self,aSet,frequency):
        self.aSet = aSet
        self.frequency = frequency

# %%
salesData = salesData.fillna(0)

# %%
#master list holds array of all frequent item objects
masterArr = []

# %%
#Input: an array of candidate objects

#checkDBfreq uses the object array to loop through each row, keeping track of how many times a subset is seen

#When finished, the frequency attribute of all apriori objects 
#in the array will contain the correct frequency for that object's set
def checkDBfreq(objArr):
    #Ensure all objects have zero frequency before looping through the data set
    for obj in objArr:
        obj.frequency = 0
        
    #For each row, consider all objects in array.
    #If the object's aSet attribute is a subset of the row, increment that object's frequency by one.
    #Continue to the next data set row and reconsider all objects...
    for index, row in salesData.iterrows():
        for obj in objArr:
            if obj.aSet.issubset(set(row)):
                obj.frequency +=1

# %%
#Input: objArr - array of apriori objects that contain correct frequencies
#       min_support - The minimum support set by user. Determines which objects are included in master array

#When finished, the master array will contain all apriori objects with frequency >= minimum support
def buildMasterArr(objArr, min_support):
    if len(objArr) == 0:
        return 
    for obj in objArr:
        if obj.frequency >= int(min_support):
            masterArr.append(obj)

# %%
#Input: objArr - Array to hold all candidate combinations before checking subsets
#       iteration - Integer that determines which frequent subsets to consider for the next group of candidates

#When finished, objArr contains the appriopriate sized powerset to consider as candidate sets
def buildCandidateSet(objArr, iteration):
    tempSet = set([])
    for obj in masterArr:
        if len(obj.aSet) == iteration - 1:
            tempSet = tempSet.union(obj.aSet)
    powerSet = itertools.combinations(tempSet, iteration)
    for item in powerSet:
        L1 = apriori(set(item), 0)
        objArr.append(L1)

# %%
#Input: objArr - Contains all possible candidate sets
#       iteration - Used to determine the appropriate size of subsets to generate

#checkFreqSubsets considers the subsets of each candidate set of one size smaller.
#These subsets are then compared to the master array apriori objects.
#If a subset cannot be found within the master array, then that subset is infrequent.
#If an infrequent subset is found, the corresponding candidate set is removed from the candidate array

#When finished, objArr will contain all potential candidates that should be used to search database frequencies
def checkFreqSubsets(objArr, iteration):
    for obj in objArr:
        powerSet = itertools.combinations(obj.aSet, iteration - 1)
        found = 0
        for item in powerSet:
            found = 0
            for thing in masterArr:
                if set(item).issubset(thing.aSet):
                    found = 1
            if found == 0:
                break
        if found == 0:
            objArr.remove(obj)

# %%
#Main function is divided into two sections
# (1), The initial frequency set of size 1 is produced. This is used as the bases for all other frequent set sizes
# (2), The loop runs until no more frequent sets are added to the master array

def main(min_support):
    
    #Start with a blank master array
    global masterArr
    masterArr = []
    
    #Compile a set of all unique values found in the dataset
    candidateSet = set()
    for index, row in salesData.iterrows():
        candidateSet = candidateSet.union(set(row))

    #Store every element in an apriori object and build the first candidate object array
    firstCandidateObjArr = []
    for item in candidateSet:
        if (item != 0):
            L1 = apriori({item}, 0)
            firstCandidateObjArr.append(L1)

    #Collect the number of occurences of each set in the dataset
    checkDBfreq(firstCandidateObjArr)
    buildMasterArr(firstCandidateObjArr, min_support)

    counter = 2 #starts at 2, since the frequent set size of 1 has already been created
    while True:
        candidateObjArr = [] #Each iteration gets its own candidateObjArr
        
        #Building the candidate set
        buildCandidateSet(candidateObjArr, counter)
        
        if counter > 2:
            #Checking subsets of candidate sets to elimate any containing non-frequent subsets
            checkFreqSubsets(candidateObjArr, counter)
            
        #Checking frequencies of candidates in the data set
        checkDBfreq(candidateObjArr)
        prevMasterLen = len(masterArr)
        
        #Adding to the master array
        buildMasterArr(candidateObjArr, min_support)
        postMasterLen = len(masterArr)
        counter +=1
        if prevMasterLen == postMasterLen:
            print("Nothing was added to master array. We are finished")
            break

    #Print all frequent sets found in the data set
    print("Freq itemsets of all sizes with min support = ", min_support, ": ")
    for obj in masterArr:
        print("Set: ", obj.aSet, " Num of occurences: ", obj.frequency)

# %%
again = "Y"
while again=="Y":
    #Prompt user for min_support level
    min_support = input("What is the minimum level of support? ")
    
    main(min_support)
    again = input("Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) ")
# Out:
# What is the minimum level of support? 3
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  3 :
# Set:  {1.0}  Num of occurences:  3
# Set:  {9.0}  Num of occurences:  7
# Set:  {11.0}  Num of occurences:  3
# Set:  {32.0}  Num of occurences:  23
# Set:  {36.0}  Num of occurences:  3
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {55.0}  Num of occurences:  3
# Set:  {65.0}  Num of occurences:  12
# Set:  {76.0}  Num of occurences:  3
# Set:  {79.0}  Num of occurences:  7
# Set:  {89.0}  Num of occurences:  11
# Set:  {101.0}  Num of occurences:  6
# Set:  {107.0}  Num of occurences:  3
# Set:  {110.0}  Num of occurences:  3
# Set:  {123.0}  Num of occurences:  4
# Set:  {147.0}  Num of occurences:  6
# Set:  {4270.0}  Num of occurences:  3
# Set:  {185.0}  Num of occurences:  6
# Set:  {204.0}  Num of occurences:  4
# Set:  {4307.0}  Num of occurences:  3
# Set:  {225.0}  Num of occurences:  4
# Set:  {237.0}  Num of occurences:  5
# Set:  {4336.0}  Num of occurences:  4
# Set:  {248.0}  Num of occurences:  3
# Set:  {255.0}  Num of occurences:  4
# Set:  {260.0}  Num of occurences:  3
# Set:  {262.0}  Num of occurences:  3
# Set:  {270.0}  Num of occurences:  3
# Set:  {271.0}  Num of occurences:  6
# Set:  {278.0}  Num of occurences:  3
# Set:  {286.0}  Num of occurences:  4
# Set:  {4393.0}  Num of occurences:  4
# Set:  {301.0}  Num of occurences:  6
# Set:  {310.0}  Num of occurences:  8
# Set:  {4424.0}  Num of occurences:  3
# Set:  {340.0}  Num of occurences:  3
# Set:  {365.0}  Num of occurences:  3
# Set:  {405.0}  Num of occurences:  7
# Set:  {413.0}  Num of occurences:  9
# Set:  {441.0}  Num of occurences:  4
# Set:  {475.0}  Num of occurences:  8
# Set:  {544.0}  Num of occurences:  6
# Set:  {548.0}  Num of occurences:  4
# Set:  {549.0}  Num of occurences:  3
# Set:  {4698.0}  Num of occurences:  8
# Set:  {653.0}  Num of occurences:  3
# Set:  {12946.0}  Num of occurences:  6
# Set:  {4764.0}  Num of occurences:  4
# Set:  {12981.0}  Num of occurences:  3
# Set:  {766.0}  Num of occurences:  3
# Set:  {4880.0}  Num of occurences:  3
# Set:  {789.0}  Num of occurences:  4
# Set:  {8985.0}  Num of occurences:  3
# Set:  {806.0}  Num of occurences:  3
# Set:  {809.0}  Num of occurences:  5
# Set:  {837.0}  Num of occurences:  3
# Set:  {4976.0}  Num of occurences:  3
# Set:  {885.0}  Num of occurences:  4
# Set:  {910.0}  Num of occurences:  4
# Set:  {924.0}  Num of occurences:  3
# Set:  {927.0}  Num of occurences:  3
# Set:  {938.0}  Num of occurences:  3
# Set:  {956.0}  Num of occurences:  4
# Set:  {961.0}  Num of occurences:  3
# Set:  {981.0}  Num of occurences:  3
# Set:  {1001.0}  Num of occurences:  4
# Set:  {1004.0}  Num of occurences:  3
# Set:  {1043.0}  Num of occurences:  4
# Set:  {13335.0}  Num of occurences:  3
# Set:  {1066.0}  Num of occurences:  4
# Set:  {1115.0}  Num of occurences:  3
# Set:  {1146.0}  Num of occurences:  3
# Set:  {1214.0}  Num of occurences:  3
# Set:  {1239.0}  Num of occurences:  4
# Set:  {1344.0}  Num of occurences:  4
# Set:  {1393.0}  Num of occurences:  3
# Set:  {1417.0}  Num of occurences:  3
# Set:  {1435.0}  Num of occurences:  3
# Set:  {1481.0}  Num of occurences:  4
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1578.0}  Num of occurences:  4
# Set:  {1592.0}  Num of occurences:  4
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1600.0}  Num of occurences:  4
# Set:  {9802.0}  Num of occurences:  4
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14029.0}  Num of occurences:  3
# Set:  {14068.0}  Num of occurences:  3
# Set:  {14098.0}  Num of occurences:  8
# Set:  {1987.0}  Num of occurences:  3
# Set:  {2052.0}  Num of occurences:  6
# Set:  {14345.0}  Num of occurences:  3
# Set:  {14386.0}  Num of occurences:  15
# Set:  {2150.0}  Num of occurences:  5
# Set:  {2202.0}  Num of occurences:  3
# Set:  {2238.0}  Num of occurences:  4
# Set:  {2242.0}  Num of occurences:  3
# Set:  {2243.0}  Num of occurences:  3
# Set:  {10441.0}  Num of occurences:  3
# Set:  {10491.0}  Num of occurences:  6
# Set:  {10515.0}  Num of occurences:  6
# Set:  {10551.0}  Num of occurences:  3
# Set:  {10579.0}  Num of occurences:  3
# Set:  {10653.0}  Num of occurences:  4
# Set:  {2654.0}  Num of occurences:  3
# Set:  {2815.0}  Num of occurences:  3
# Set:  {7205.0}  Num of occurences:  4
# Set:  {3136.0}  Num of occurences:  3
# Set:  {11383.0}  Num of occurences:  3
# Set:  {3270.0}  Num of occurences:  3
# Set:  {3291.0}  Num of occurences:  3
# Set:  {3366.0}  Num of occurences:  5
# Set:  {3510.0}  Num of occurences:  3
# Set:  {3774.0}  Num of occurences:  3
# Set:  {4055.0}  Num of occurences:  3
# Set:  {1.0, 39.0}  Num of occurences:  3
# Set:  {2052.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 2052.0}  Num of occurences:  3
# Set:  {9.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 9.0}  Num of occurences:  3
# Set:  {9.0, 310.0}  Num of occurences:  3
# Set:  {9.0, 413.0}  Num of occurences:  3
# Set:  {39.0, 271.0}  Num of occurences:  5
# Set:  {14098.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 14098.0}  Num of occurences:  4
# Set:  {10515.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 10515.0}  Num of occurences:  6
# Set:  {10515.0, 405.0}  Num of occurences:  3
# Set:  {789.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 789.0}  Num of occurences:  4
# Set:  {38.0, 286.0}  Num of occurences:  4
# Set:  {286.0, 39.0}  Num of occurences:  3
# Set:  {32.0, 38.0}  Num of occurences:  3
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {32.0, 14386.0}  Num of occurences:  3
# Set:  {32.0, 4698.0}  Num of occurences:  3
# Set:  {32.0, 185.0}  Num of occurences:  3
# Set:  {32.0, 1486.0}  Num of occurences:  3
# Set:  {544.0, 39.0}  Num of occurences:  3
# Set:  {544.0, 48.0}  Num of occurences:  4
# Set:  {36.0, 38.0}  Num of occurences:  3
# Set:  {548.0, 39.0}  Num of occurences:  3
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {4393.0, 38.0}  Num of occurences:  3
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {14386.0, 38.0}  Num of occurences:  3
# Set:  {110.0, 38.0}  Num of occurences:  3
# Set:  {4393.0, 39.0}  Num of occurences:  4
# Set:  {806.0, 39.0}  Num of occurences:  3
# Set:  {809.0, 39.0}  Num of occurences:  3
# Set:  {1066.0, 39.0}  Num of occurences:  3
# Set:  {301.0, 39.0}  Num of occurences:  4
# Set:  {1578.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {14386.0, 39.0}  Num of occurences:  6
# Set:  {310.0, 39.0}  Num of occurences:  4
# Set:  {1592.0, 39.0}  Num of occurences:  3
# Set:  {1594.0, 39.0}  Num of occurences:  4
# Set:  {65.0, 39.0}  Num of occurences:  5
# Set:  {3136.0, 39.0}  Num of occurences:  3
# Set:  {837.0, 39.0}  Num of occurences:  3
# Set:  {79.0, 39.0}  Num of occurences:  6
# Set:  {89.0, 39.0}  Num of occurences:  6
# Set:  {4698.0, 39.0}  Num of occurences:  6
# Set:  {1115.0, 39.0}  Num of occurences:  3
# Set:  {101.0, 39.0}  Num of occurences:  4
# Set:  {2150.0, 39.0}  Num of occurences:  3
# Set:  {885.0, 39.0}  Num of occurences:  3
# Set:  {910.0, 39.0}  Num of occurences:  4
# Set:  {1677.0, 39.0}  Num of occurences:  4
# Set:  {147.0, 39.0}  Num of occurences:  3
# Set:  {1435.0, 39.0}  Num of occurences:  3
# Set:  {413.0, 39.0}  Num of occurences:  5
# Set:  {4270.0, 39.0}  Num of occurences:  3
# Set:  {185.0, 39.0}  Num of occurences:  3
# Set:  {441.0, 39.0}  Num of occurences:  3
# Set:  {2238.0, 39.0}  Num of occurences:  4
# Set:  {2242.0, 39.0}  Num of occurences:  3
# Set:  {1481.0, 39.0}  Num of occurences:  4
# Set:  {204.0, 39.0}  Num of occurences:  3
# Set:  {1486.0, 39.0}  Num of occurences:  7
# Set:  {4055.0, 39.0}  Num of occurences:  3
# Set:  {475.0, 39.0}  Num of occurences:  6
# Set:  {3291.0, 39.0}  Num of occurences:  3
# Set:  {225.0, 39.0}  Num of occurences:  3
# Set:  {237.0, 39.0}  Num of occurences:  4
# Set:  {4336.0, 39.0}  Num of occurences:  3
# Set:  {248.0, 39.0}  Num of occurences:  3
# Set:  {10491.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 4393.0}  Num of occurences:  3
# Set:  {48.0, 809.0}  Num of occurences:  3
# Set:  {48.0, 1066.0}  Num of occurences:  3
# Set:  {48.0, 301.0}  Num of occurences:  3
# Set:  {65.0, 301.0}  Num of occurences:  4
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Set:  {48.0, 310.0}  Num of occurences:  4
# Set:  {48.0, 1594.0}  Num of occurences:  5
# Set:  {48.0, 1344.0}  Num of occurences:  3
# Set:  {48.0, 65.0}  Num of occurences:  6
# Set:  {48.0, 837.0}  Num of occurences:  3
# Set:  {48.0, 79.0}  Num of occurences:  3
# Set:  {48.0, 10579.0}  Num of occurences:  3
# Set:  {48.0, 340.0}  Num of occurences:  3
# Set:  {48.0, 89.0}  Num of occurences:  6
# Set:  {48.0, 4698.0}  Num of occurences:  5
# Set:  {48.0, 1115.0}  Num of occurences:  3
# Set:  {48.0, 101.0}  Num of occurences:  5
# Set:  {48.0, 2150.0}  Num of occurences:  3
# Set:  {48.0, 110.0}  Num of occurences:  3
# Set:  {48.0, 910.0}  Num of occurences:  3
# Set:  {48.0, 1677.0}  Num of occurences:  4
# Set:  {48.0, 12946.0}  Num of occurences:  3
# Set:  {48.0, 147.0}  Num of occurences:  3
# Set:  {48.0, 405.0}  Num of occurences:  5
# Set:  {48.0, 413.0}  Num of occurences:  4
# Set:  {48.0, 10653.0}  Num of occurences:  3
# Set:  {48.0, 938.0}  Num of occurences:  3
# Set:  {48.0, 4270.0}  Num of occurences:  3
# Set:  {48.0, 185.0}  Num of occurences:  4
# Set:  {48.0, 956.0}  Num of occurences:  3
# Set:  {48.0, 2238.0}  Num of occurences:  3
# Set:  {48.0, 2242.0}  Num of occurences:  3
# Set:  {48.0, 1481.0}  Num of occurences:  3
# Set:  {48.0, 1486.0}  Num of occurences:  5
# Set:  {48.0, 981.0}  Num of occurences:  3
# Set:  {48.0, 475.0}  Num of occurences:  4
# Set:  {48.0, 237.0}  Num of occurences:  4
# Set:  {48.0, 10491.0}  Num of occurences:  4
# Set:  {89.0, 405.0}  Num of occurences:  3
# Set:  {4698.0, 1677.0}  Num of occurences:  3
# Set:  {4698.0, 1486.0}  Num of occurences:  5
# Set:  {1677.0, 1486.0}  Num of occurences:  3
# Set:  {48.0, 9.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 14098.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 10515.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 10515.0, 405.0}  Num of occurences:  3
# Set:  {48.0, 789.0, 39.0}  Num of occurences:  3
# Set:  {38.0, 286.0, 39.0}  Num of occurences:  3
# Set:  {32.0, 38.0, 39.0}  Num of occurences:  3
# Set:  {32.0, 48.0, 39.0}  Num of occurences:  6
# Set:  {32.0, 4698.0, 39.0}  Num of occurences:  3
# Set:  {32.0, 1486.0, 39.0}  Num of occurences:  3
# Set:  {32.0, 48.0, 14386.0}  Num of occurences:  3
# Set:  {4393.0, 38.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 38.0, 39.0}  Num of occurences:  7
# Set:  {48.0, 4393.0, 38.0}  Num of occurences:  3
# Set:  {48.0, 110.0, 38.0}  Num of occurences:  3
# Set:  {48.0, 4393.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 809.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 1066.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 301.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 14386.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 310.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 1594.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 65.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 837.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 89.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 4698.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 1115.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 101.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 1677.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 910.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 413.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 4270.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 185.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 2238.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 2242.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 1481.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 1486.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 475.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 237.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 10491.0, 39.0}  Num of occurences:  4
# Set:  {4698.0, 1486.0, 39.0}  Num of occurences:  3
# Set:  {48.0, 89.0, 405.0}  Num of occurences:  3
# Set:  {48.0, 4393.0, 38.0, 39.0}  Num of occurences:  3
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 4
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  4 :
# Set:  {9.0}  Num of occurences:  7
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {79.0}  Num of occurences:  7
# Set:  {89.0}  Num of occurences:  11
# Set:  {101.0}  Num of occurences:  6
# Set:  {123.0}  Num of occurences:  4
# Set:  {147.0}  Num of occurences:  6
# Set:  {185.0}  Num of occurences:  6
# Set:  {204.0}  Num of occurences:  4
# Set:  {225.0}  Num of occurences:  4
# Set:  {237.0}  Num of occurences:  5
# Set:  {4336.0}  Num of occurences:  4
# Set:  {255.0}  Num of occurences:  4
# Set:  {271.0}  Num of occurences:  6
# Set:  {286.0}  Num of occurences:  4
# Set:  {4393.0}  Num of occurences:  4
# Set:  {301.0}  Num of occurences:  6
# Set:  {310.0}  Num of occurences:  8
# Set:  {405.0}  Num of occurences:  7
# Set:  {413.0}  Num of occurences:  9
# Set:  {441.0}  Num of occurences:  4
# Set:  {475.0}  Num of occurences:  8
# Set:  {544.0}  Num of occurences:  6
# Set:  {548.0}  Num of occurences:  4
# Set:  {4698.0}  Num of occurences:  8
# Set:  {12946.0}  Num of occurences:  6
# Set:  {4764.0}  Num of occurences:  4
# Set:  {789.0}  Num of occurences:  4
# Set:  {809.0}  Num of occurences:  5
# Set:  {885.0}  Num of occurences:  4
# Set:  {910.0}  Num of occurences:  4
# Set:  {956.0}  Num of occurences:  4
# Set:  {1001.0}  Num of occurences:  4
# Set:  {1043.0}  Num of occurences:  4
# Set:  {1066.0}  Num of occurences:  4
# Set:  {1239.0}  Num of occurences:  4
# Set:  {1344.0}  Num of occurences:  4
# Set:  {1481.0}  Num of occurences:  4
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1578.0}  Num of occurences:  4
# Set:  {1592.0}  Num of occurences:  4
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1600.0}  Num of occurences:  4
# Set:  {9802.0}  Num of occurences:  4
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14098.0}  Num of occurences:  8
# Set:  {2052.0}  Num of occurences:  6
# Set:  {14386.0}  Num of occurences:  15
# Set:  {2150.0}  Num of occurences:  5
# Set:  {2238.0}  Num of occurences:  4
# Set:  {10491.0}  Num of occurences:  6
# Set:  {10515.0}  Num of occurences:  6
# Set:  {10653.0}  Num of occurences:  4
# Set:  {7205.0}  Num of occurences:  4
# Set:  {3366.0}  Num of occurences:  5
# Set:  {1677.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 1677.0}  Num of occurences:  4
# Set:  {910.0, 39.0}  Num of occurences:  4
# Set:  {39.0, 271.0}  Num of occurences:  5
# Set:  {48.0, 405.0}  Num of occurences:  5
# Set:  {48.0, 789.0}  Num of occurences:  4
# Set:  {14098.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 14098.0}  Num of occurences:  4
# Set:  {10515.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 10515.0}  Num of occurences:  6
# Set:  {413.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 413.0}  Num of occurences:  4
# Set:  {38.0, 286.0}  Num of occurences:  4
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {544.0, 48.0}  Num of occurences:  4
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {4393.0, 39.0}  Num of occurences:  4
# Set:  {301.0, 39.0}  Num of occurences:  4
# Set:  {10491.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {14386.0, 39.0}  Num of occurences:  6
# Set:  {310.0, 39.0}  Num of occurences:  4
# Set:  {1594.0, 39.0}  Num of occurences:  4
# Set:  {2238.0, 39.0}  Num of occurences:  4
# Set:  {65.0, 39.0}  Num of occurences:  5
# Set:  {1481.0, 39.0}  Num of occurences:  4
# Set:  {1486.0, 39.0}  Num of occurences:  7
# Set:  {79.0, 39.0}  Num of occurences:  6
# Set:  {89.0, 39.0}  Num of occurences:  6
# Set:  {4698.0, 39.0}  Num of occurences:  6
# Set:  {475.0, 39.0}  Num of occurences:  6
# Set:  {101.0, 39.0}  Num of occurences:  4
# Set:  {237.0, 39.0}  Num of occurences:  4
# Set:  {65.0, 301.0}  Num of occurences:  4
# Set:  {48.0, 10491.0}  Num of occurences:  4
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Set:  {48.0, 310.0}  Num of occurences:  4
# Set:  {48.0, 185.0}  Num of occurences:  4
# Set:  {48.0, 1594.0}  Num of occurences:  5
# Set:  {48.0, 65.0}  Num of occurences:  6
# Set:  {48.0, 1486.0}  Num of occurences:  5
# Set:  {48.0, 89.0}  Num of occurences:  6
# Set:  {48.0, 4698.0}  Num of occurences:  5
# Set:  {48.0, 475.0}  Num of occurences:  4
# Set:  {48.0, 101.0}  Num of occurences:  5
# Set:  {48.0, 237.0}  Num of occurences:  4
# Set:  {4698.0, 1486.0}  Num of occurences:  5
# Set:  {48.0, 1486.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 10515.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 89.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 4698.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 475.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 413.0, 39.0}  Num of occurences:  4
# Set:  {32.0, 48.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 101.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 38.0, 39.0}  Num of occurences:  7
# Set:  {48.0, 237.0, 39.0}  Num of occurences:  4
# Set:  {48.0, 10491.0, 39.0}  Num of occurences:  4
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 5
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  5 :
# Set:  {9.0}  Num of occurences:  7
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {79.0}  Num of occurences:  7
# Set:  {89.0}  Num of occurences:  11
# Set:  {101.0}  Num of occurences:  6
# Set:  {147.0}  Num of occurences:  6
# Set:  {185.0}  Num of occurences:  6
# Set:  {237.0}  Num of occurences:  5
# Set:  {271.0}  Num of occurences:  6
# Set:  {301.0}  Num of occurences:  6
# Set:  {310.0}  Num of occurences:  8
# Set:  {405.0}  Num of occurences:  7
# Set:  {413.0}  Num of occurences:  9
# Set:  {475.0}  Num of occurences:  8
# Set:  {544.0}  Num of occurences:  6
# Set:  {4698.0}  Num of occurences:  8
# Set:  {12946.0}  Num of occurences:  6
# Set:  {809.0}  Num of occurences:  5
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14098.0}  Num of occurences:  8
# Set:  {2052.0}  Num of occurences:  6
# Set:  {14386.0}  Num of occurences:  15
# Set:  {2150.0}  Num of occurences:  5
# Set:  {10491.0}  Num of occurences:  6
# Set:  {10515.0}  Num of occurences:  6
# Set:  {3366.0}  Num of occurences:  5
# Set:  {65.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 65.0}  Num of occurences:  6
# Set:  {4698.0, 1486.0}  Num of occurences:  5
# Set:  {1486.0, 39.0}  Num of occurences:  7
# Set:  {48.0, 1486.0}  Num of occurences:  5
# Set:  {39.0, 79.0}  Num of occurences:  6
# Set:  {39.0, 271.0}  Num of occurences:  5
# Set:  {48.0, 405.0}  Num of occurences:  5
# Set:  {48.0, 10515.0}  Num of occurences:  6
# Set:  {89.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 89.0}  Num of occurences:  6
# Set:  {4698.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 4698.0}  Num of occurences:  5
# Set:  {475.0, 39.0}  Num of occurences:  6
# Set:  {413.0, 39.0}  Num of occurences:  5
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {48.0, 101.0}  Num of occurences:  5
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {14386.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Set:  {48.0, 1594.0}  Num of occurences:  5
# Set:  {48.0, 1486.0, 39.0}  Num of occurences:  5
# Set:  {48.0, 4698.0, 39.0}  Num of occurences:  5
# Set:  {32.0, 48.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 38.0, 39.0}  Num of occurences:  7
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 6
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  6 :
# Set:  {9.0}  Num of occurences:  7
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {79.0}  Num of occurences:  7
# Set:  {89.0}  Num of occurences:  11
# Set:  {101.0}  Num of occurences:  6
# Set:  {147.0}  Num of occurences:  6
# Set:  {185.0}  Num of occurences:  6
# Set:  {271.0}  Num of occurences:  6
# Set:  {301.0}  Num of occurences:  6
# Set:  {310.0}  Num of occurences:  8
# Set:  {405.0}  Num of occurences:  7
# Set:  {413.0}  Num of occurences:  9
# Set:  {475.0}  Num of occurences:  8
# Set:  {544.0}  Num of occurences:  6
# Set:  {4698.0}  Num of occurences:  8
# Set:  {12946.0}  Num of occurences:  6
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14098.0}  Num of occurences:  8
# Set:  {2052.0}  Num of occurences:  6
# Set:  {14386.0}  Num of occurences:  15
# Set:  {10491.0}  Num of occurences:  6
# Set:  {10515.0}  Num of occurences:  6
# Set:  {48.0, 65.0}  Num of occurences:  6
# Set:  {1486.0, 39.0}  Num of occurences:  7
# Set:  {39.0, 79.0}  Num of occurences:  6
# Set:  {48.0, 10515.0}  Num of occurences:  6
# Set:  {89.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 89.0}  Num of occurences:  6
# Set:  {4698.0, 39.0}  Num of occurences:  6
# Set:  {475.0, 39.0}  Num of occurences:  6
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {14386.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Set:  {32.0, 48.0, 39.0}  Num of occurences:  6
# Set:  {48.0, 38.0, 39.0}  Num of occurences:  7
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 7
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  7 :
# Set:  {9.0}  Num of occurences:  7
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {79.0}  Num of occurences:  7
# Set:  {89.0}  Num of occurences:  11
# Set:  {310.0}  Num of occurences:  8
# Set:  {405.0}  Num of occurences:  7
# Set:  {413.0}  Num of occurences:  9
# Set:  {475.0}  Num of occurences:  8
# Set:  {4698.0}  Num of occurences:  8
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14098.0}  Num of occurences:  8
# Set:  {14386.0}  Num of occurences:  15
# Set:  {1486.0, 39.0}  Num of occurences:  7
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Set:  {48.0, 38.0, 39.0}  Num of occurences:  7
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 8
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  8 :
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {89.0}  Num of occurences:  11
# Set:  {310.0}  Num of occurences:  8
# Set:  {413.0}  Num of occurences:  9
# Set:  {475.0}  Num of occurences:  8
# Set:  {4698.0}  Num of occurences:  8
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1594.0}  Num of occurences:  8
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14098.0}  Num of occurences:  8
# Set:  {14386.0}  Num of occurences:  15
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 38.0}  Num of occurences:  8
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {48.0, 14386.0}  Num of occurences:  8
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 9
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  9 :
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {89.0}  Num of occurences:  11
# Set:  {413.0}  Num of occurences:  9
# Set:  {1486.0}  Num of occurences:  9
# Set:  {1677.0}  Num of occurences:  9
# Set:  {14386.0}  Num of occurences:  15
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {38.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 39.0}  Num of occurences:  41
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) Y
# What is the minimum level of support? 10
# Nothing was added to master array. We are finished
# Freq itemsets of all sizes with min support =  10 :
# Set:  {32.0}  Num of occurences:  23
# Set:  {38.0}  Num of occurences:  16
# Set:  {39.0}  Num of occurences:  73
# Set:  {48.0}  Num of occurences:  60
# Set:  {65.0}  Num of occurences:  12
# Set:  {89.0}  Num of occurences:  11
# Set:  {14386.0}  Num of occurences:  15
# Set:  {32.0, 48.0}  Num of occurences:  13
# Set:  {32.0, 39.0}  Num of occurences:  11
# Set:  {48.0, 39.0}  Num of occurences:  41
# Set:  {38.0, 39.0}  Num of occurences:  11
# Run again with a different minimum support level? (Enter 'Y' to continue. Anything else to exit) n
